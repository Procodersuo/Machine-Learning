# %%
import pandas as pd  
animaldf=pd.DataFrame({'Animals': ["Elephant"], 'Biology': ["Elephant is a large animal"]})
students=pd.DataFrame({'Student-Name': ["Asad, Talha , Hamza"], 
'Contact-Number':["0311-XXXXX","0311-XXXXX","0311-XXXXX"],
'Addesss':["XYZ,Lahore", "ujk,Lahore", "ABC,Lahore"]
})
students
